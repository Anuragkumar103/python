# %% [markdown]
# Arithmetic operators

# %%
a=10
b=20
c =a+b
d =b-a
e= a*b
f = b/a
g = a%b
h =a//b
i = a**b
print( c,d,e,f,g,h,i)
# Out:
# 30 10 200 2.0 10 0 100000000000000000000

# %% [markdown]
# assignment operators

# %%
a = 10 
b+=10
c-=10
d*=10 
e/=10 
f//=10 
g**=10 
print ( a,b,c,d,e,f,g,)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 a = 10
#       2 b+=10
# ----> 3 c-=10
#       4 d*=10
#       5 e/=10
#
# NameError: name 'c' is not defined
