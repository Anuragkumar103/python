# %%
poem =''' Twinkle Twinkle Little Star is a classic children's
song and nursery rhyme. The song is based on the Jane Taylor poem '''
print ( poem)
# Out:
#  Twinkle Twinkle Little Star is a classic children's
# song and nursery rhyme. The song is based on the Jane Taylor poem

# %%
lst = [8,2,5,'hello',True, 'apple', 5,2]
print (lst)  # list
# Out:
# [8, 2, 5, 'hello', True, 'apple', 5, 2]

# %%
lst = (65,2,5,'hello',True, 'apple', 5,2)
print (lst) #tuples
# Out:
# (1, 2, 5, 'hello', True, 'apple', 5, 2)

# %%
lst = {1,2,5,'hello',True, 'apple', 5,2}
print (lst) #set
# Out:
# {1, 2, 5, 'apple', 'hello'}

# %%
car_info = {
  "brand": "Ford",
  "model": "Mustang",
  "year": 1964
}
print(car_info) # distionaries
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %% [markdown]
# type casting

# %%
a = 2 
b = int(input("Enter a number:"))
c = a + b 
print(c)
# Out:
# 27

# %%
a=10
print (a)
# Out:
# 10

# %%
name= "anurag" 
print (name)
# Out:
# anurag

# %%
nameside  ="i'm anurag kumar"
print (nameside)
# Out:
# i'm anurag kumar

# %% [markdown]
# boolean

# %%
b=2565
print (a==0)
# Out:
# False

# %%
print (a>21)
# Out:
# True

# %% [markdown]
# list

# %%
lst = [8,2,5,'hello',True, 'apple', 5,2]
print (lst)
# Out:
# [8, 2, 5, 'hello', True, 'apple', 5, 2]

# %%
fruits= ["apple","banana","orange",]
print (fruits)
# Out:
# {'apple', 'banana', 'orange'}

# %%
details= ["Anurag", 21,26,26,"DSMNRU"]
print (details)
# Out:
# ['Anurag', 21, 26, 26, 'DSMNRU']

# %%
lst = (56,2,5,'hello',True, 'apple', 5,2)
print (lst) #tuples
# Out:
# (56, 2, 5, 'hello', True, 'apple', 5, 2)

# %%
games = ("BGMI","cod," ,"game","minimilita","cod")
print(games)
# Out:
# ('BGMI', 'cod,', 'game', 'minimilita', 'cod')

# %%
set={"bgmi","BGMI","cod", "cod","game","minimilita","pubg"}
print (set)
# Out:
# {'BGMI', 'cod', 'bgmi', 'game', 'minimilita', 'pubg'}

# %%
car_info = {
  "brand": "Ford",
  "model": "Mustang",
  "year":  "1964",
  "owner": "shelby"
}
print(car_info)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': '1964', 'owner': 'shelby'}

# %%
my_details= {
"name":"Anurag",
"institution":"dsmnru",
"age":"22",
"marks":"99.999999999999999999999999"
}
print(my_details)
# Out:
# {'name': 'Anurag', 'institution': 'dsmnru', 'age': '22', 'marks': '659'}

# %%
type(my_details)
# Out:
# dict

# %%
type(game)
# Out:
# tuple

# %%
type(fruits)
# Out:
# set

# %%
type(lst)
# Out:
# tuple

# %%
name="anurag"
type (name)
# Out:
# str

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
num={20,25,56,56,56,25,45,45,25,56,}
print(num)       #it was unordered
# Out:
# {56, 25, 20, 45}

# %%
abc=[10,20,30,40,50,60,70,80]
print (abc)
type (abc)
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]
# list
