# %% [markdown]
# SLICING

# %%
apps = [ 'google', 'drive','swiggy','ola','uber','airlearn','rep','instagram','facebook','netflix','hundai']
print (apps)
# Out:
# ['google', 'drive', 'swiggy', 'ola', 'uber', 'airlearn', 'rep', 'instagram', 'facebook', 'netflix', 'hundai']

# %%
for app in apps:
    print (app)
# Out:
# google
# drive
# swiggy
# ola
# uber
# airlearn
# rep
# instagram
# facebook
# netflix
# hundai

# %%
print (apps[2])
# Out:
# swiggy

# %%
print (apps[0])
# Out:
# google

# %%
print (apps[-4])
# Out:
# instagram

# %%
print (apps[2:4])
# Out:
# ['swiggy', 'ola']

# %%
print (apps[1:4])
# Out:
# ['drive', 'swiggy', 'ola']

# %%
print (apps[-6:-2])
# Out:
# ['airlearn', 'rep', 'instagram', 'facebook']

# %% [markdown]
# indexing

# %%
print (apps[1:7:])
# Out:
# ['drive', 'swiggy', 'ola', 'uber', 'airlearn', 'rep']

# %% [markdown]
# LIST METHODS
#
# appends() - to add  iten at the end of the list
#
# insert() - to add item at any specific position in the list
#
# pop() - to delete item using its index position
#
# remove() - to delete items using item name
#
# copy() - to make a duplicate of the list
#
# sort() - to sort the list in a particular order
#
# extend() - to combine two list into a single list
#
# clear() - to delete all the items from the list but not the list

# %%
movies = [' your name',' GOT',  'your fault', 'your fault ' ,' over dose ', ' AOT' ,'insecption']

# %%
movies.append('Matrix')
print (movies)
# Out:
# [' your name', ' GOT', 'your fault', 'your fault ', ' over dose ', ' AOT', 'insecption', 'Matrix']

# %%
movies.insert (2, 'anurag')

# %%
print(movies)
# Out:
# [' your name', ' GOT', 'anurag', 'your fault', 'your fault ', ' over dose ', ' AOT', 'insecption', 'Matrix']

# %%
movies.pop()
# Out:
# 'Matrix'

# %%
movies.pop()
# Out:
# 'insecption'

# %%
movies.pop()
# Out:
# ' AOT'

# %%
movies.pop()
# Out:
# ' over dose '

# %%
movies.pop()
# Out:
# 'your fault '

# %%
movies.pop()
# Out:
# 'your fault'

# %%
movies.remove(' your name ')

# %%
print (movies)
# Out:
# [' your name', ' GOT']

# %%
movies.remove('your  fault')

# %%
print ( movies)
# Out:
# [' your name', ' GOT', 'anurag']

# %%
nums = [1,2,3,4,5,6,7,8,9 ]

# %%
mycopy= nums

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
mycopy
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
nums.pop()
# Out:
# 9

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
mycopy
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
mycopy2 = nums.copy()

# %%
nums.pop()
# Out:
# 8

# %%
nums
# Out:
# [1, 2, 3, 4, 5, 6, 7]
